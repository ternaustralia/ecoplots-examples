# %% [markdown]
# # Retrieving Bird Occurrence Data from the TERN Ecosystem API
#
# In this tutorial, we will walk through the process of connecting to the TERN Ecosystem API to retrieve specific data related to ecosystem processes. By the end of this tutorial, you'll understand how to establish a connection, define a query, and process the returned data.

# %% [markdown]
# ### Importing Necessary Libraries
#
# To connect to the TERN API and handle the data, we'll need two libraries:
#
# - `http.client`: Helps establish the connection and make the request.
# - `json`: Assists in formatting our query into JSON format, which is required by the API.

# %%
import http.client
import json

# %% [markdown]
# ### Setting Up the Connection
#
# To retrieve data, we first need to establish a connection to the API's server. In this case, we're connecting to TERN's test server at "ecoplots-test.tern.org.au".

# %%
conn = http.client.HTTPSConnection("ecoplots-test.tern.org.au")

# %% [markdown]
# ### Defining the Query
#
# To instruct the API on what data we're interested in, we define a query. This query specifies:
#
# - The dataset we're interested in (`tern-ecosystem-processes`).
# - The feature type, which is a specific TERN classification.
# - The site ID, representing a particular location or site.

# %%
payload = json.dumps({
  "query": {
    "dataset": [
      "http://linked.data.gov.au/dataset/tern-ecosystem-processes"
    ],
    "feature_type": [
      "http://linked.data.gov.au/def/tern-cv/0c30e871-63ae-4f84-a37c-ef6e7ce02928"
    ],
    "site_id": [
      "https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540"
    ]
  }
})

# %% [markdown]
# ### Defining Headers
# For our request to be successfully processed by the server, we need to define certain headers. The headers include the necessary API key for authorisation and specify the content type as JSON.

# %%
headers = {
  'X-Api-Key': 'api_key',
  'Content-Type': 'application/json'
}

# %% [markdown]
# ### Sending the API Request
#
# Now that we have set up our connection details, query, and headers (including the API key), we can proceed to send our request to the TERN API. We'll use the `request` method of our connection object to do this.

# %%
# Send the POST request to the TERN API
conn.request("POST", "/api/v1.0/data/tern-ecosystem-processes?dformat=csv", payload, headers)

# %% [markdown]
# ### Processing the Response
#
# Once we send our request, the TERN API will process it and send back a response. We need to capture this response and process it to extract the data we're interested in.

# %%
# Capture the response from the API
res = conn.getresponse()

# Read the data from the response
data = res.read()

# %% [markdown]
# ### Displaying the Data
#
# Let's take a look at the data we received from the TERN API. We'll decode it from its byte format and print it out to view its content.

# %%
# Decode the data and print it
decoded_data = data.decode("utf-8")
print(decoded_data)
# Out:
# datasetTitle,projectTitle,siteName,parentSiteName,latitude_Degree,longitude_Degree,topParentSiteName,siteVisitName,siteVisitStartDate,siteVisitEndDate,featureType,featureId,parentFeatureId,scientificName,scientificName,scientificNameResultTime,scientificNameMethod,individualCount_number,individualCountResultTime,individualCountMethod
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-0,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Coracina lineata,Coracina lineata,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,1,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-1,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Melloria quoyi,Melloria quoyi,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,3,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-10,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Pandion cristatus,Pandion cristatus,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,1,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-11,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Chalcophaps indica,Chalcophaps indica,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,1,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-12,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Gerygone palpebrosa,Gerygone palpebrosa,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,1,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-13,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Gerygone palpebrosa,Gerygone palpebrosa,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,2,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-14,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Sphecotheres vieilloti,Sphecotheres vieilloti,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,2,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-15,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Meliphaga gracilis,Meliphaga gracilis,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,8,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-16,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Meliphaga gracilis,Meliphaga gracilis,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,3,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-17,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Meliphaga gracilis,Meliphaga gracilis,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,4,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-18,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Pachycephala simplex,Pachycephala simplex,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Myzomela obscura,Myzomela obscura,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,2,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96
# TERN Ecosystem Processes,Bird-survey,"Daintree Rainforest, Cape Tribulation",N/A,-16.1056,145.378,"Daintree Rainforest, Cape Tribulation",20141023,2014-10-23T00:00:00,2014-10-25T00:00:00,bird occurrence,http://linked.data.gov.au/dataset/tern-ecosystem-processes/dataset-bird_survey/site_visit_id-daintree_rainforest__cape_tribulation_20141023-row_index-9,https://w3id.org/tern/resources/d90ffc82-61fa-40ff-83cf-e0f1072f2540,Myzomela obscura,Myzomela obscura,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96,6,2014-10-23T00:00:00,http://linked.data.gov.au/def/tern-cv/16f25771-0b84-494f-8cf9-8ecf6f41fc96

# %% [markdown]
# ### Data Import and Cleanup
#
# Now that we have retrieved data from the API, the next step is to process this data into a structured format suitable for analysis. This will involve importing the data into a DataFrame and cleaning it up.

# %%
import pandas as pd
from io import StringIO

# Convert the API response string to a DataFrame
df = pd.read_csv(StringIO(data.decode("utf-8")))

# Display the first few rows of the dataframe
df.head()
# Out:
#                datasetTitle projectTitle  \
# 0  TERN Ecosystem Processes  Bird-survey
# 1  TERN Ecosystem Processes  Bird-survey
# 2  TERN Ecosystem Processes  Bird-survey
# 3  TERN Ecosystem Processes  Bird-survey
# 4  TERN Ecosystem Processes  Bird-survey
#
#                                 siteName  parentSiteName  latitude_Degree  \
# 0  Daintree Rainforest, Cape Tribulation             NaN         -16.1056
# 1  Daintree Rainforest, Cape Tribulation             NaN         -16.1056
# 2  Daintree Rainforest, Cape Tribulation             NaN         -16.1056
# 3  Daintree Rainforest, Cape Tribulation             NaN         -16.1056
# 4  Daintree Rainforest, Cape Tribulation             NaN         -16.1056
#
#    longitude_Degree                      topParentSiteName  siteVisitName  \
# 0           145.378  Daintree Rainforest, Cape Tribulation       20141023
# 1           145.378  Daintree Rainforest, Cape Tribulation       20141023
# 2           145.378  Daintree Rainforest, Cape Tribulation       20141023
# 3           145.378  Daintree Rainforest, Cape Tribulation       20141023
# 4           145.378  Daintree Rainforest, Cape Tribulation       20141023
#
#     siteVisitStartDate     siteVisitEndDate      featureType  \
# 0  2014-10-23T00:00:00  2014-10-25T00:00:00  bird occurrence
# 1  2014-10-23T00:00:00  2014-10-25T00:00:00  bird occurrence
# 2  2014-10-23T00:00:00  2014-10-25T00:00:00  bird occurrence
# 3  2014-10-23T00:00:00  2014-10-25T00:00:00  bird occurrence
# 4  2014-10-23T00:00:00  2014-10-25T00:00:00  bird occurrence
#
#                                            featureId  \
# 0  http://linked.data.gov.au/dataset/tern-ecosyst...
# 1  http://linked.data.gov.au/dataset/tern-ecosyst...
# 2  http://linked.data.gov.au/dataset/tern-ecosyst...
# 3  http://linked.data.gov.au/dataset/tern-ecosyst...
# 4  http://linked.data.gov.au/dataset/tern-ecosyst...
#
#                                      parentFeatureId       scientificName  \
# 0  https://w3id.org/tern/resources/d90ffc82-61fa-...     Coracina lineata
# 1  https://w3id.org/tern/resources/d90ffc82-61fa-...       Melloria quoyi
# 2  https://w3id.org/tern/resources/d90ffc82-61fa-...    Pandion cristatus
# 3  https://w3id.org/tern/resources/d90ffc82-61fa-...   Chalcophaps indica
# 4  https://w3id.org/tern/resources/d90ffc82-61fa-...  Gerygone palpebrosa
#
#       scientificName.1 scientificNameResultTime  \
# 0     Coracina lineata      2014-10-23T00:00:00
# 1       Melloria quoyi      2014-10-23T00:00:00
# 2    Pandion cristatus      2014-10-23T00:00:00
# 3   Chalcophaps indica      2014-10-23T00:00:00
# 4  Gerygone palpebrosa      2014-10-23T00:00:00
#
#                                 scientificNameMethod  individualCount_number  \
# 0  http://linked.data.gov.au/def/tern-cv/16f25771...                       1
# 1  http://linked.data.gov.au/def/tern-cv/16f25771...                       3
# 2  http://linked.data.gov.au/def/tern-cv/16f25771...                       1
# 3  http://linked.data.gov.au/def/tern-cv/16f25771...                       1
# 4  http://linked.data.gov.au/def/tern-cv/16f25771...                       1
#
#   individualCountResultTime                              individualCountMethod
# 0       2014-10-23T00:00:00  http://linked.data.gov.au/def/tern-cv/16f25771...
# 1       2014-10-23T00:00:00  http://linked.data.gov.au/def/tern-cv/16f25771...
# 2       2014-10-23T00:00:00  http://linked.data.gov.au/def/tern-cv/16f25771...
# 3       2014-10-23T00:00:00  http://linked.data.gov.au/def/tern-cv/16f25771...
# 4       2014-10-23T00:00:00  http://linked.data.gov.au/def/tern-cv/16f25771...

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# Before diving deep into advanced analyses, it's often a good idea to get a sense of the data we're working with. We'll start by visualising the distributions of certain columns.
#
# Let's see which bird species are the most commonly sighted in our dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the style
sns.set_style("whitegrid")

# Plotting
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='scientificName', order=df['scientificName'].value_counts().index)
plt.title('Frequency of Bird Sightings by Species')
plt.xlabel('Count')
plt.ylabel('Bird Species')

# Set x-axis ticks to integers
plt.xticks(range(0, max(df['scientificName'].value_counts()) + 1, 1))

plt.show()

# %% [markdown]
# ### Bird Species Diversity
#
# To evaluate the diversity of bird species within our dataset, we can compute the Shannon Diversity Index. This metric considers both the number of species and the evenness of the species' proportions.

# %%
import numpy as np

# Calculate Shannon Diversity Index
species_counts = df['scientificName'].value_counts()
species_proportions = species_counts / species_counts.sum()
shannon_diversity_index = -np.sum(species_proportions * np.log(species_proportions))

print(f"Shannon Diversity Index: {shannon_diversity_index:.4f}")
# Out:
# Shannon Diversity Index: 3.4082

# %% [markdown]
# ### Pie Chart of Top 5 Bird Species
#
# Let's visualise the proportion of the top 5 most commonly sighted bird species in our dataset using a pie chart.

# %%
# Get the top 5 bird species and their counts
top_species = df['scientificName'].value_counts().head(5)

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_species, labels=top_species.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Top 5 Bird Species')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### Conclusion
#
# In this tutorial, we've covered the basics of bird occurrence data analysis using the TERN Ecosystem API. We explored data retrieval, preprocessing, and visualisation steps. While this tutorial provides a fundamental understanding, there are numerous avenues for further exploration and in-depth analysis. Researchers and enthusiasts can dive deeper into this dataset to uncover ecological insights and conduct species-specific studies. The dataset offers ample opportunities for expanding our knowledge of avian biodiversity through data-driven approaches.
